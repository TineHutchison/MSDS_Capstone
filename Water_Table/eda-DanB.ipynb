# %%
import pandas as pd
from bokeh.io import push_notebook, output_notebook
from bokeh.plotting import figure, show
output_notebook()
GoogleAPIKey = "AIzaSyAY_9Hdvx940vnez9esb7C58I0sD1ZAlq4"

# %%
train_data = pd.read_csv('./tanzania-X-train.csv', header=0)
train_target = pd.read_csv('./tanzania-y-train.csv', header=0)

# %%
train_data.info()

# %%
train_data.describe

# %%
train_data['status_group'] = train_target.status_group.astype('category')

# %%
from bokeh.plotting import gmap
from bokeh.layouts import column
from bokeh.models import GMapOptions
from bokeh.palettes import brewer
from bokeh.models import CategoricalColorMapper
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral5
from bokeh.transform import linear_cmap

# %%
mapoptions = GMapOptions(lat=train_data.latitude.median(), lng=train_data.longitude.median(), zoom=6)

# %%
#colors = brewer["Spectral"][len(train_data.status_group.unique())]
#colormap = {x: colors[i] for i, x in enumerate(train_data.status_group.unique())}
#colors = [colormap[x] for x in train_data.status_group]
#categories = list(train_data.status_group.unique())
#color_mapper = CategoricalColorMapper(factors=categories)
#cmap = factor_cmap('status_group', palette=Spectral5, factors=sorted(train_data.status_group.unique()), end=1)
p1 = gmap(GoogleAPIKey,mapoptions)
p1.circle(x='longitude', y='latitude', source=train_data[train_data['status_group'] == 'functional'],
         color='green')
p2 = gmap(GoogleAPIKey,mapoptions)
p2.circle(x='longitude', y='latitude', source=train_data[train_data['status_group'] == 'functional needs repair'],
         color='yellow')
p3 = gmap(GoogleAPIKey,mapoptions)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['status_group'] == 'non functional'],
         color='red')

show(column(p1,p2,p3))

# %%
p3 = gmap(GoogleAPIKey,mapoptions)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['construction_year'] != 0],
         color="green", size=3,alpha=.15)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['construction_year'] == 0],
         color="red", size=3,alpha=.15)
#heatmap_layer = p3.heatmap_layer(locations)
#p3.add_layer(heatmap_layer)
show(p3)

# %%
p3 = gmap(GoogleAPIKey,mapoptions)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['construction_year'] != 0],
         color=linear_cmap('construction_year', 'Plasma256', 1970, 2010), alpha =.2)
show(p3)

# %%
p3 = gmap(GoogleAPIKey,mapoptions)
train_data["yearrecorded"] = pd.DatetimeIndex(train_data['date_recorded']).year

p3.circle(x='longitude', y='latitude', source=train_data[train_data['yearrecorded'] == 2011],
         color="orange", size=3, alpha=.1)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['yearrecorded'] == 2012],
         color="purple", size=3, alpha=.1)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['yearrecorded'] == 2013],
         color="green", size=3, alpha=.1)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['yearrecorded'] == 2002],
         color="red", size=3, alpha=.1)
p3.circle(x='longitude', y='latitude', source=train_data[train_data['yearrecorded'] == 2004],
         color="blue", size=3, alpha=.1)
show(p3)
