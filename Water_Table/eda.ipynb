# %%
import pandas as pd
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cdc3f2e0-04cc-48b1-9555-f2afb48644ad">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cdc3f2e0-04cc-48b1-9555-f2afb48644ad">Loading BokehJS ...</span>
#     </div>

# %%
test_data = pd.read_csv('/home/tine/PycharmProjects/pred498/MSDS_Capstone/Water_Table/tanzania-x-test.csv', header=0)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14850 entries, 0 to 14849
# Data columns (total 40 columns):
# id                       14850 non-null int64
# amount_tsh               14850 non-null float64
# date_recorded            14850 non-null object
# funder                   13981 non-null object
# gps_height               14850 non-null int64
# installer                13973 non-null object
# longitude                14850 non-null float64
# latitude                 14850 non-null float64
# wpt_name                 14850 non-null object
# num_private              14850 non-null int64
# basin                    14850 non-null object
# subvillage               14751 non-null object
# region                   14850 non-null object
# region_code              14850 non-null int64
# district_code            14850 non-null int64
# lga                      14850 non-null object
# ward                     14850 non-null object
# population               14850 non-null int64
# ...

# %%
test_data.describe
# Out:
# <bound method NDFrame.describe of           id  amount_tsh date_recorded                          funder  \
# 0      50785         0.0    2013-02-04                            Dmdd
# 1      51630         0.0    2013-02-04          Government Of Tanzania
# 2      17168         0.0    2013-02-01                             NaN
# 3      45559         0.0    2013-01-22                      Finn Water
# 4      49871       500.0    2013-03-27                          Bruder
# 5      52449         0.0    2013-03-04          Government Of Tanzania
# 6      24806         0.0    2011-03-02          Government Of Tanzania
# 7      28965         0.0    2013-01-25                            Finw
# 8      36301        30.0    2013-01-23                          Unicef
# 9      54122         0.0    2013-03-18         Lawatefuka Water Supply
# 10       419         5.0    2013-10-03                 Germany Republi
# 11     45750         0.0    2013-02-27                    World Vision
# ...
